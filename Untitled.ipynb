# %%
# !python --version
# Out:
# Python 3.12.4

# %%
# !git clone https://github.com/THU-MIG/yolov10.git
# Out:
# Cloning into 'yolov10'...

# %%
cd yolov10
# Out:
# D:\project\yolov10

# %%
# !pip install .
# Out:
# ^C
# Defaulting to user installation because normal site-packages is not writeable
# Processing d:\project\yolov10
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for ultralytics: filename=ultralytics-8.1.34-py3-none-any.whl size=735275 sha256=91c14566c9fd6a6f14c48a14e628843297049b4da57f2d65a0a01f31105adcbd
#   Stored in directory: C:\Users\tandu\AppData\Local\Temp\pip-ephem-wheel-cache-3gocnc7b\wheels\15\40\de\f3c28a1d4ba435ab7631e07b998291308b4c2b5cdee8c1a510
# Successfully built ultralytics
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.1.34
#     Uninstalling ultralytics-8.1.34:
#       Successfully uninstalled ultralytics-8.1.34
# ...

# %%
import os
import urllib.request

# Create a directory for the weights in the current working directory
weights_dir = os.path.join(os.getcwd(), "weights")
os.makedirs(weights_dir, exist_ok=True)

# URLs of the weight files
urls = [
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10s.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10m.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10b.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10x.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10l.pt"
]

# Download each file
for url in urls:
    file_name = os.path.join(weights_dir, os.path.basename(url))
    urllib.request.urlretrieve(url, file_name)
    print(f"Downloaded {file_name}")
# Out:
# Downloaded D:\project\yolov10\weights\yolov10n.pt
# Downloaded D:\project\yolov10\weights\yolov10s.pt
# Downloaded D:\project\yolov10\weights\yolov10m.pt
# Downloaded D:\project\yolov10\weights\yolov10b.pt
# Downloaded D:\project\yolov10\weights\yolov10x.pt
# Downloaded D:\project\yolov10\weights\yolov10l.pt

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=../weights/yolov10n.pt source=../test_images/1.jpg
# Out:
# Ultralytics YOLOv8.1.34 ðŸš€ Python-3.12.4 torch-2.3.1+cpu CPU (11th Gen Intel Core(TM) i5-11400H 2.70GHz)
# YOLOv10n summary (fused): 285 layers, 2762608 parameters, 63840 gradients, 8.6 GFLOPs
#
# image 1/1 D:\project\yolov10\..\test_images\1.jpg: 448x640 4 17s, 104.0ms
# Speed: 2.5ms preprocess, 104.0ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs\detect\predict
# ðŸ’¡ Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=../weights/yolov10n.pt source=../test_images/2.png
# Out:
# Ultralytics YOLOv8.1.34 ðŸš€ Python-3.12.4 torch-2.3.1+cpu CPU (11th Gen Intel Core(TM) i5-11400H 2.70GHz)
# YOLOv10n summary (fused): 285 layers, 2762608 parameters, 63840 gradients, 8.6 GFLOPs
#
# image 1/1 D:\project\yolov10\..\test_images\2.png: 288x640 11 28s, 85.6ms
# Speed: 5.0ms preprocess, 85.6ms inference, 12.1ms postprocess per image at shape (1, 3, 288, 640)
# Results saved to runs\detect\predict
# ðŸ’¡ Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=train epochs=100 batch=16 plots=True model=weights/yolov10n.pt data=custom_data.yaml

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=runs/detect/train/weights/best.pt source=test_images_1/opencv_frame_12.png
# Out:
# Ultralytics YOLOv8.1.34 ðŸš€ Python-3.12.4 torch-2.3.1+cpu CPU (11th Gen Intel Core(TM) i5-11400H 2.70GHz)
# YOLOv10n summary (fused): 285 layers, 2695976 parameters, 0 gradients, 8.2 GFLOPs
#
# image 1/1 D:\project\yolov10\test_images_1\opencv_frame_12.png: 480x640 1 Bia-Truc-Bach, 108.4ms
# Speed: 1.5ms preprocess, 108.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict
# ðŸ’¡ Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=runs/detect/train/weights/best.pt source=testvd.mp4
# Out:
# Ultralytics YOLOv8.1.34 ðŸš€ Python-3.12.4 torch-2.3.1+cpu CPU (11th Gen Intel Core(TM) i5-11400H 2.70GHz)
# YOLOv10n summary (fused): 285 layers, 2695976 parameters, 0 gradients, 8.2 GFLOPs
#
# video 1/1 (frame 1/644) D:\project\yolov10\testvd.mp4: 384x640 1 Bia-Truc-Bach, 86.1ms
# video 1/1 (frame 2/644) D:\project\yolov10\testvd.mp4: 384x640 1 Bia-Truc-Bach, 77.4ms
# video 1/1 (frame 3/644) D:\project\yolov10\testvd.mp4: 384x640 (no detections), 76.4ms
# video 1/1 (frame 4/644) D:\project\yolov10\testvd.mp4: 384x640 (no detections), 76.7ms
# video 1/1 (frame 5/644) D:\project\yolov10\testvd.mp4: 384x640 1 Bia-Truc-Bach, 73.1ms
# video 1/1 (frame 6/644) D:\project\yolov10\testvd.mp4: 384x640 (no detections), 76.0ms
# video 1/1 (frame 7/644) D:\project\yolov10\testvd.mp4: 384x640 1 Bia-Truc-Bach, 74.6ms
# video 1/1 (frame 8/644) D:\project\yolov10\testvd.mp4: 384x640 1 Bia-Truc-Bach, 74.1ms
# video 1/1 (frame 9/644) D:\project\yolov10\testvd.mp4: 384x640 1 Bia-Truc-Bach, 74.2ms
# ...

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=runs/detect/train/weights/best.pt source=testvd2.mp4
# Out:
# Ultralytics YOLOv8.1.34 ðŸš€ Python-3.12.4 torch-2.3.1+cpu CPU (11th Gen Intel Core(TM) i5-11400H 2.70GHz)
# YOLOv10n summary (fused): 285 layers, 2695976 parameters, 0 gradients, 8.2 GFLOPs
#
# video 1/1 (frame 1/2467) D:\project\yolov10\testvd2.mp4: 384x640 (no detections), 93.0ms
# video 1/1 (frame 2/2467) D:\project\yolov10\testvd2.mp4: 384x640 1 Fanta, 75.0ms
# video 1/1 (frame 3/2467) D:\project\yolov10\testvd2.mp4: 384x640 (no detections), 72.8ms
# video 1/1 (frame 4/2467) D:\project\yolov10\testvd2.mp4: 384x640 (no detections), 82.6ms
# video 1/1 (frame 5/2467) D:\project\yolov10\testvd2.mp4: 384x640 (no detections), 87.7ms
# video 1/1 (frame 6/2467) D:\project\yolov10\testvd2.mp4: 384x640 (no detections), 75.1ms
# video 1/1 (frame 7/2467) D:\project\yolov10\testvd2.mp4: 384x640 (no detections), 71.9ms
# video 1/1 (frame 8/2467) D:\project\yolov10\testvd2.mp4: 384x640 (no detections), 185.6ms
# ...

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=runs/detect/train/weights/best.pt source=testvd3.mp4
# Out:
# Ultralytics YOLOv8.1.34 ðŸš€ Python-3.12.4 torch-2.3.1+cpu CPU (11th Gen Intel Core(TM) i5-11400H 2.70GHz)
# YOLOv10n summary (fused): 285 layers, 2695976 parameters, 0 gradients, 8.2 GFLOPs
#
# video 1/1 (frame 1/659) D:\project\yolov10\testvd3.mp4: 640x384 1 Fanta, 1 Heineken, 236.9ms
# video 1/1 (frame 2/659) D:\project\yolov10\testvd3.mp4: 640x384 1 Fanta, 1 Heineken, 92.1ms
# video 1/1 (frame 3/659) D:\project\yolov10\testvd3.mp4: 640x384 1 Fanta, 1 Heineken, 107.0ms
# video 1/1 (frame 4/659) D:\project\yolov10\testvd3.mp4: 640x384 1 Fanta, 1 Heineken, 155.8ms
# video 1/1 (frame 5/659) D:\project\yolov10\testvd3.mp4: 640x384 1 Fanta, 1 Heineken, 118.9ms
# video 1/1 (frame 6/659) D:\project\yolov10\testvd3.mp4: 640x384 1 Fanta, 1 Heineken, 101.3ms
# video 1/1 (frame 7/659) D:\project\yolov10\testvd3.mp4: 640x384 1 Fanta, 1 Heineken, 146.7ms
# video 1/1 (frame 8/659) D:\project\yolov10\testvd3.mp4: 640x384 1 Fanta, 1 Heineken, 299.1ms
# ...
